# %%
# importing required modules

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import re
import util
import random

# %%
# loading data
df=util.get_processed_data("./data/collections_math.csv")
df.head()
# Out:
#                           collection_id  sequence_id  \
# 0  0008d66a-753f-4639-8634-81bb3abb3269            3
# 1  0008d66a-753f-4639-8634-81bb3abb3269            5
# 2  0008d66a-753f-4639-8634-81bb3abb3269            2
# 3  0008d66a-753f-4639-8634-81bb3abb3269            1
# 4  0008d66a-753f-4639-8634-81bb3abb3269            4
#
#                             resource_id                               title  \
# 0  2ee6f80f-0851-4cfa-b4bf-2655e9c46ab7  Solve the Linear equation: _______
# 1  15a464a4-a2d8-41dd-b00e-ff7fea0aa720                   If , then _______
# 2  0b248202-12a9-405b-acd1-4ab8250e4198                   If , then _______
# 3  231eb4ad-d0e8-4e94-a552-f8bd2358a47a  Solve the linear equation: _______
# 4  81c6995c-dd95-418e-a8c4-c22d8ccd32e9  Solve the linear equation: _______
#
#                                          description  \
# 0         Solve the Linear equation:            [2]
# 1                          If      , then      [-4]
# 2    If      , then      [1/5]. &nbsp;Please writ...
# 3    Solve the linear equation:            [1/2] ...
# 4       Solve the linear equation:            [-18]
#
#                                                 text
# 0  Solve the Linear equation Solve the Linear equ...
# 1                                    If then If then
# 2  If then If then nbsp Please write your answer ...
# 3  Solve the linear equation Solve the linear equ...
# 4  Solve the linear equation Solve the linear equ...

# %%
# generating text column using title and description
df['text'] = df[['title', 'description']].apply(lambda x: ' '.join(x), axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27754 entries, 0 to 27753
# Data columns (total 6 columns):
# collection_id    27754 non-null object
# sequence_id      27754 non-null int64
# resource_id      27754 non-null object
# title            27754 non-null object
# description      27754 non-null object
# text             27754 non-null object
# dtypes: int64(1), object(5)
# memory usage: 1.3+ MB

# %%
# generating collections
collections = util.get_collections(df)

# %%
# processing the text column
for col in collections:
    lrs = []
    for i,text in enumerate(col["texts"]):
        new_text = ""
        for word in text.split():
            if len(word)>2:
                new_text+=word+" "
        if new_text.strip()!="":
            lrs.append(new_text.strip().lower())
    col["texts"] = lrs

# %%
# generating new valid paiwise learning resources data
data=[]
for col in collections:
    ran = min(len(col["sequence_ids"]),len(col["resource_ids"]),len(col["texts"])) 
    for i in range(0,ran-1):
        new_data=[]
        
        
        new_data.append(col["id"])
        new_data.append(col["id"])
        
        new_data.append(col["sequence_ids"][i])
        new_data.append(col["sequence_ids"][i+1])
        
        new_data.append(col["resource_ids"][i])
        new_data.append(col["resource_ids"][i+1])
        
        new_data.append(col["texts"][i])
        new_data.append(col["texts"][i+1])
        
        data.append(new_data)

# %%
# creating a dataframe for the valid resources 
new_df=pd.DataFrame(data = data, columns=["collection_id1","collection_id2","sequence_id1","sequence_id2","resource_id1",
                                    "resource_id2","text1","text2"])
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23229 entries, 0 to 23228
# Data columns (total 8 columns):
# collection_id1    23229 non-null object
# collection_id2    23229 non-null object
# sequence_id1      23229 non-null int64
# sequence_id2      23229 non-null int64
# resource_id1      23229 non-null object
# resource_id2      23229 non-null object
# text1             23229 non-null object
# text2             23229 non-null object
# dtypes: int64(2), object(6)
# memory usage: 1.4+ MB

# %%
# generating new invalid paiwise learning resources data


invalid_data=[]
col_id=df.collection_id.unique()

for i in range(0,31397):
    new_row=[]
    
    col_1=random.choice(collections)
    col_2=random.choice(collections)
    
    min1=min(len(col_1["sequence_ids"]),len(col_1["resource_ids"]),len(col_1["texts"]))
    min2=min(len(col_2["sequence_ids"]),len(col_2["resource_ids"]),len(col_2["texts"]))
    
    
    val_1=random.randint(0,min1-1)
    val_2=random.randint(0,min2-1)
    
#     print(len(col_1["sequence_ids"]))
#     print(len(col_2["sequence_ids"]))
    
#     print("\n")
    
#     print(len(col_1["resource_ids"]))
#     print(len(col_2["resource_ids"]))

#     print("\n")
    
#     print(len(col_1["texts"]))
#     print(len(col_2["texts"]))

#     print("\n")

    
    seq_id1 = col_1["sequence_ids"][val_1]
    seq_id2 = col_2["sequence_ids"][val_2]
    
    res_id1 = col_1["resource_ids"][val_1]
    res_id2 = col_2["resource_ids"][val_2]    
    
    text1 = col_1["texts"][val_1]
    text2 = col_2["texts"][val_2]    
    
    new_row.append(col_1["id"])
    new_row.append(col_2["id"])
   
    new_row.append(seq_id1)
    new_row.append(seq_id2)
    
    new_row.append(res_id1)
    new_row.append(res_id2)
    
    new_row.append(text1)
    new_row.append(text2)
    
    invalid_data.append(new_row)

# %%
# creating a dataframe for the invalide resources 

new_invalid_df=pd.DataFrame(data = invalid_data, columns=["collection_id1","collection_id2","sequence_id1","sequence_id2","resource_id1",
                                    "resource_id2","text1","text2"])
new_invalid_df.head()
# Out:
#                          collection_id1                        collection_id2  \
# 0  935b0ee5-003f-425f-aaab-b9fa2c88cb49  90146ff5-07a4-4595-aa39-8b4376cd2388
# 1  9235bfb8-05d2-429e-8e0d-26693168b5e9  05093016-2cda-4677-8c44-8dda982e9874
# 2  fcff006e-2336-4aae-b11e-52280e74f05c  20a333a2-3847-43ef-8000-4cfd95b70284
# 3  85ef1b0a-0635-4fce-9dbd-ead8436d9e5e  7b44d0d3-8065-4579-a0b1-48dc3b4988e4
# 4  51a5b6cb-651a-46e8-8f3e-14d2b484feaa  e5860f3c-db5c-46af-9ee2-4df7b28ad846
#
#    sequence_id1  sequence_id2                          resource_id1  \
# 0             3             3  881779b6-843f-11e3-a253-12313f070480
# 1             1            25  f55be2a5-bd1c-44e5-81db-6a96826eed76
# 2             2             5  1d0511b6-2bd7-4203-b876-fc0aded263d9
# 3             4             1  b4955af3-488a-44e3-a467-3f65f5049669
# 4             3             8  38064450-e156-4137-8837-20ac5843bb04
#
#                            resource_id2  \
# 0  e6f963be-5afc-4f4b-858b-a7b1824544de
# 1  a945bd1b-67ca-49df-a80f-f6b23b7beabc
# 2  8c253ab9-ad9f-4231-9a57-bc30b026ea48
# 3  9a26d2b9-7699-451e-8f93-a78dd06d75d5
# 4  ca84e919-edbe-445b-ae72-7bff6c183860
#
#                                                text1  \
# 0  equation line this video describes how find th...
# 1  lesson 17: write expressions which letters sta...
# 2  australia experienced major pest australia exp...
# 3  multi-digit multiplication practice 5764 [4611...
# 4  4-6 multiplying polynomials (pt. youtube prese...
#
#                                                text2
# 0  draw model show your thinking kelly buys tarp ...
# 1  change mixed number into improper fraction 1(1...
# 2  asteroids orbiting sun video clip showing all ...
# 3  grasshopper covered distance yards grasshopper...
# 4  systems equations with elimination challenge s...

# %%
# appending valid and invalid dataframe 
final_df = new_df.append(new_invalid_df , ignore_index=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54626 entries, 0 to 54625
# Data columns (total 8 columns):
# collection_id1    54626 non-null object
# collection_id2    54626 non-null object
# sequence_id1      54626 non-null int64
# sequence_id2      54626 non-null int64
# resource_id1      54626 non-null object
# resource_id2      54626 non-null object
# text1             54626 non-null object
# text2             54626 non-null object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %%
final_df.head()
# Out:
#                          collection_id1                        collection_id2  \
# 0  0008d66a-753f-4639-8634-81bb3abb3269  0008d66a-753f-4639-8634-81bb3abb3269
# 1  0008d66a-753f-4639-8634-81bb3abb3269  0008d66a-753f-4639-8634-81bb3abb3269
# 2  0008d66a-753f-4639-8634-81bb3abb3269  0008d66a-753f-4639-8634-81bb3abb3269
# 3  0008d66a-753f-4639-8634-81bb3abb3269  0008d66a-753f-4639-8634-81bb3abb3269
# 4  001bf2c6-8ede-478a-9b8b-d7750488cb1b  001bf2c6-8ede-478a-9b8b-d7750488cb1b
#
#    sequence_id1  sequence_id2                          resource_id1  \
# 0             1             2  231eb4ad-d0e8-4e94-a552-f8bd2358a47a
# 1             2             3  0b248202-12a9-405b-acd1-4ab8250e4198
# 2             3             4  2ee6f80f-0851-4cfa-b4bf-2655e9c46ab7
# 3             4             5  81c6995c-dd95-418e-a8c4-c22d8ccd32e9
# 4             1             2  1b922fae-619f-4f52-9551-663b3206e4e5
#
#                            resource_id2  \
# 0  0b248202-12a9-405b-acd1-4ab8250e4198
# 1  2ee6f80f-0851-4cfa-b4bf-2655e9c46ab7
# 2  81c6995c-dd95-418e-a8c4-c22d8ccd32e9
# 3  15a464a4-a2d8-41dd-b00e-ff7fea0aa720
# 4  8b9c50e6-e568-48f7-afee-91f46c8fb523
#
#                                                text1  \
# 0  solve the linear equation: _______ solve the l...
# 1  then _______ then [1/5]. &nbsp;please write yo...
# 2  solve the linear equation: _______ solve the l...
# 3  solve the linear equation: _______ solve the l...
# 4  lesson i'll say addition subtraction sentence....
#
#                                                text2
# 0  then _______ then [1/5]. &nbsp;please write yo...
# 1  solve the linear equation: _______ solve the l...
# 2  solve the linear equation: _______ solve the l...
# 3                             then _______ then [-4]
# 4  subtracting fractions from whole numbers i'll ...

# %%
# saving data into data files
new_df.to_csv("./data/math_valid_pairwise_res.csv")
new_invalid_df.to_csv("./data/math_invalid_pairwise_res.csv")
final_df.to_csv("./data/math_final_pairwise.csv")
